# %%
import requests
from bs4 import BeautifulSoup
import io
from PyPDF2 import PdfFileReader
import wget
from selenium import webdriver
import os

# %%
url = "https://cdsco.gov.in/opencms/opencms/en/Notifications/Alerts/"
read = requests.get(url)
html_content = read.content
soup = BeautifulSoup(html_content, "html.parser")
 
list_of_pdf = set()
l = soup.find_all('td')
for i in range(len(l)):
    p[i] = l.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [39], in <module>
#       6 list_of_pdf = set()
#       7 l = soup.find_all('td')
# ----> 8 p = l.find_all('a')
#
# File /usr/lib/python3/dist-packages/bs4/element.py:2173, in ResultSet.__getattr__(self, key)
#    2171 def __getattr__(self, key):
#    2172     """Raise a helpful exception to explain a common code fix."""
# -> 2173     raise AttributeError(
#    2174         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2175     )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
print(soup.prettify()[:1000])
# Out:
# <html>
#  <head>
#   <title>
#    Alerts
#   </title>
#   <link href="/opencms/opencms/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <script src="/opencms/export/system/modules/CDSCO.WEB/resources/js/jquery-1.12.4.js" type="text/javascript">
#   </script>
#   <link href="/opencms/export/system/modules/CDSCO.WEB/resources/css/animate.min.css" rel="stylesheet" type="text/css"/>
#   <link href="/opencms/export/system/modules/CDSCO.WEB/resources/css/owl.theme.css" rel="stylesheet" type="text/css"/>
#   <link href="/opencms/export/system/modules/CDSCO.WEB/resources/css/owl.carousel.css" rel="stylesheet" type="text/css"/>
#   <script src="/opencms/export/system/modules/CDSCO.WEB/resources/js/owl.carousel.min.js" type="text/javascript">
#   </script>
#   <script src="/opencms/export/system/modules/CDSCO.WEB/resources/js/wow.min.js" type="text/javascript">
#   </script>
# ...

# %%
soup
# Out:
# <html>
# <head>
# <title>Alerts</title>
# <link href="/opencms/opencms/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script src="/opencms/export/system/modules/CDSCO.WEB/resources/js/jquery-1.12.4.js" type="text/javascript"></script>
# <link href="/opencms/export/system/modules/CDSCO.WEB/resources/css/animate.min.css" rel="stylesheet" type="text/css"/>
# <link href="/opencms/export/system/modules/CDSCO.WEB/resources/css/owl.theme.css" rel="stylesheet" type="text/css"/>
# <link href="/opencms/export/system/modules/CDSCO.WEB/resources/css/owl.carousel.css" rel="stylesheet" type="text/css"/>
# <script src="/opencms/export/system/modules/CDSCO.WEB/resources/js/owl.carousel.min.js" type="text/javascript"></script>
# <script src="/opencms/export/system/modules/CDSCO.WEB/resources/js/wow.min.js" type="text/javascript"></script>
# <script src="/opencms/export/system/modules/CDSCO.WEB/resources/js/bootstrap.min.js" type="text/javascript"></script>
# ...

# %%
soup.find_all("a")
# Out:
# [<a class="skip_mc white" href="#section2" style="font-size: 20px;" title="Skip to main content"><i class="fa fa-reply-all fa-rotate-270"></i></a>,
#  <a class="white" href="/opencms/opencms/en/ScreenReader/">Screen Reader</a>,
#  <a class="white desc" href="#">A<sup>-</sup> </a>,
#  <a class="white norm" href="#" onclick="window.location.reload()">A</a>,
#  <a class="white inc" href="#">A<sup>+</sup>
#  </a>,
#  <a href="/opencms/opencms/en/Home/" target="_blank">
#  <img alt="CDSCO logo" class="shrink" src="/opencms/export/sites/CDSCO_WEB/Image_folder/logo/cdscologo_lbg.png"/>
#  </a>,
#  <a href="http://icdra2020.in/" target="_blank"> <img alt="ICDRA logo" class="img-responsive" src="/opencms/export/sites/CDSCO_WEB/Image_folder/logo/icdra_logo_new2.png"/>
#  </a>,
#  <a href="https://swachhbharat.mygov.in/" target="_blank"> <img alt="swach bharat logo" class="img-responsive" src="/opencms/export/sites/CDSCO_WEB/Image_folder/logo/swach-bharat.jpg"/>
#  </a>,
# ...

# %%
l = soup.find_all("a")

# %%
dpdf = []
for i in range(len(l)):
    if (l[i].find("i",class_="fa fa-file-pdf-o") != None):
        dpdf.append(i)
        print(i)
# Out:
# 135
# 136
# 137
# 138
# 139
# 140
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 153
# 154
# 155
# 156
# 157
# 158
# 159
# 160
# 161
# 162
# 163
# 164
# 165
# 166
# 167
# 168
# 169
# 170
# 171
# 172
# 173
# 174
# 175
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 185
# 186
# 187
# 188
# 189
# 190
# 191
# 192
# 193
# 194
# 195
# 196
# 197
# 198
# 199
# 200
# 201
# 202
# 203
# 204
# 205
# 206
# 207
# 208
# 209
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# 218
# 219
# 220
# 221
# 222
# 223
# 224
# 225
# 226
# 227
# 228
# 229
# 230
# 231
# 232
# 233
# 234
# 235
# 236
# 237
# 238
# 239
# 240
# 241
# 242
# 243
# 244
# 245
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# 256
# 257
# 258
# 259
# 260
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# 272
# 273
# 274
# 275
# 276
# 277
# 278
# 279
# 280
# 281
# 282
# 283
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# 292
# 293
# 294
# 295
# 296
# 297
# 298
# 299
# 300
# ...

# %%
l[212].find("i",class_="fa fa-file-pdf-o")
# Out:
# <i class="fa fa-file-pdf-o" style="color: red"></i>

# %%
(l[212].find("i",class_="fa fa-file-pdf-o")) != None
# Out:
# True

# %%
dpdf[1]
# Out:
# 136

# %%
<a href="/opencms/opencms/system/modules/CDSCO.WEB/elements/download_file_division.jsp?num_id=MTk1">

# %%
for i in dpdf:
    current_link = l[i].get('href')

# %%
link = str('https://cdsco.gov.in/') + l[146].get('href')

# %%
wget.download(link)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [126], in <module>
# ----> 1 wget.download(link)
#
# File /usr/local/lib/python3.9/dist-packages/wget.py:526, in download(url, out, bar)
#     524 else:
#     525     binurl = url
# --> 526 (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527 filename = detect_filename(url, out, headers)
#     528 if outdir:
#
# File /usr/lib/python3.9/urllib/request.py:239, in urlretrieve(url, filename, reporthook, data)
#     222 """
#     223 Retrieve a URL into a temporary location on disk.
#     224
#    (...)
#     235 data file as well as the resulting HTTPMessage object.
#     236 """
#     237 url_type, path = _splittype(url)
# --> 239 with contextlib.closing(urlopen(url, data)) as fp:
#     240     headers = fp.info()
#     242     # Just return the local path and the "headers" for file://
# ...

# %%
wget.download("https://cdsco.gov.in/opencms/opencms/system/modules/CDSCO.WEB/elements/download_file_division.jsp?num_id=ODEyMw==")
# Out:
# 100% [..............................................................] 241 / 241
# 'download_file_division.jsp'

# %%
url = "https://cdsco.gov.in/opencms/opencms/system/modules/CDSCO.WEB/elements/download_file_division.jsp?num_id=ODEyMw=="
read = requests.get(url)
html_content = read.content
soup = BeautifulSoup(html_content, "html.parser")

# %%
soup.find("iframe")
# Out:
# <iframe height="100%" src="/opencms/resources/UploadCDSCOWeb/2018/UploadAlertsFiles/Drugjan22 Alert List.pdf" target="_blank" width="100%">
# </iframe>

# %%
wget.download("https://cdsco.gov.in/opencms/resources/UploadCDSCOWeb/2018/UploadAlertsFiles/Drug Alert Listfeb22.pdf")
# Out:
# 100% [........................................................] 240131 / 240131
# 'Drug Alert Listfeb22.pdf'
